# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
path = "/content/drive/MyDrive/Colab Notebooks/chocolates-multivariate-csv.csv"
df = pd.read_csv(path)

# %%
df
# Out:
#       UGive  Age  IGive
# 0         1   10      2
# 1         2   15      4
# 2         3   20      6
# 3         4   25      8
# 4         5   30     10
# ...     ...  ...    ...
# 1095   1096   35   1996
# 1096   1097   40   1997
# 1097   1098   45   1999
# 1098   1099   50   2001
# 1099   1100   55   2003
#
# [1100 rows x 3 columns]

# %%
x = np.array(df.iloc[:,:2])
y = np.array(df["IGive"])

# %%
lr = LinearRegression()

# %%
lr.fit(x,y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
conf = lr.coef_
print(conf)
# Out:
# [1.82      0.0110303]

# %%
intercept = lr.intercept_
print(intercept)
# Out:
# 0.4515151515150819

# %%
print(y)
# Out:
# [   2    4    6 ... 1999 2001 2003]

# %%
y_pred = lr.predict(x)
print(y_pred)
# Out:
# [   2.38181818    4.2569697     6.13212121 ... 1999.30787879 2001.1830303
#  2003.05818182]

# %%
plt.plot(x,y)
# Out:
# [<matplotlib.lines.Line2D at 0x7f5b46413910>,
#  <matplotlib.lines.Line2D at 0x7f5b46413c50>]
